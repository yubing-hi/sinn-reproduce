# %%
import torch
print(torch.cuda.is_available())
# Out:
# True

# %%
# !git clone https://github.com/yubing-hi/sinn-reproduce.git
# %cd sinn-reproduce
# Out:
# Cloning into 'sinn-reproduce'...
# remote: Enumerating objects: 88, done.
# remote: Counting objects: 100% (88/88), done.
# remote: Compressing objects: 100% (58/58), done.
# remote: Total 88 (delta 37), reused 78 (delta 27), pack-reused 0 (from 0)
# Receiving objects: 100% (88/88), 1.28 MiB | 19.03 MiB/s, done.
# Resolving deltas: 100% (37/37), done.
# /kaggle/working/sinn-reproduce

# %%
# !pwd
# !ls
# Out:
# /kaggle/working/sinn-reproduce
# collect_reddit.py	 image	       preprocess.py	   src
# collect_twitter.py	 input	       README.md	   test.sh
# collect_twitter_user.py  main_sinn.py  run_all_methods.sh  training.py
# convert_data.py		 modules.py    run_grid_search.sh  working
# CONVERT_DATA_README.md	 plotting.py   simulate.py

# %%
# !git pull
# Out:
# Already up to date.

# %%
# !pip install configargparse
# Out:
# Collecting configargparse
#   Downloading configargparse-1.7.5-py3-none-any.whl.metadata (23 kB)
# Downloading configargparse-1.7.5-py3-none-any.whl (27 kB)
# Installing collected packages: configargparse
# Successfully installed configargparse-1.7.5

# %%
import os
import sys
import warnings
import torch

# 屏蔽 SyntaxWarning
warnings.filterwarnings("ignore", category=SyntaxWarning)

# 屏蔽 XLA/TensorFlow/CUDA 重复注册日志
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'  # 只显示 ERROR
os.environ['XLA_PYTHON_CLIENT_PREALLOCATE'] = 'false'

# !bash run_all_methods.sh
# Out:
# /kaggle/working/sinn-reproduce/main_sinn.py:32: SyntaxWarning: invalid escape sequence '\i'
#   help='Number of units in neural network. $L\in\{8,12,16\}$.')
# /kaggle/working/sinn-reproduce/main_sinn.py:34: SyntaxWarning: invalid escape sequence '\i'
#   help='Number of layers in neural network. $L\in\{3,5,7\}$.')
# /kaggle/working/sinn-reproduce/main_sinn.py:36: SyntaxWarning: invalid escape sequence '\i'
#   help='$\\alpha\in\{0.1,1.0,5.0\}$. ')
# /kaggle/working/sinn-reproduce/main_sinn.py:38: SyntaxWarning: invalid escape sequence '\i'
#   help='$\\beta\in\{0.1,1.0,5.0\}$. ')
# /kaggle/working/sinn-reproduce/main_sinn.py:43: SyntaxWarning: invalid escape sequence '\i'
#   help='dimension of latent space $K\in\{1,2,3\}$. ')
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1773650869.674318     132 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1773650869.725403     132 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1773650870.168019     132 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1773650870.168064     132 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1773650870.168071     132 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1773650870.168079     132 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# Loading dataset
# Finished loading dataset
# Traceback (most recent call last):
#   File "/kaggle/working/sinn-reproduce/main_sinn.py", line 362, in <module>
#     main_sinn(opt.dataset, opt.method, logging_root)
#   File "/kaggle/working/sinn-reproduce/main_sinn.py", line 329, in main_sinn
#     test_res, att_res, zu_res = prediction(use_profile, test_dataloader, model, batch_size, nclasses)
#                                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/kaggle/working/sinn-reproduce/main_sinn.py", line 183, in prediction
#     device = next(model.parameters()).device
#              ^^^^^^^^^^^^^^^^^^^^^^^^
# StopIteration
# /kaggle/working/sinn-reproduce/main_sinn.py:32: SyntaxWarning: invalid escape sequence '\i'
#   help='Number of units in neural network. $L\in\{8,12,16\}$.')
# /kaggle/working/sinn-reproduce/main_sinn.py:34: SyntaxWarning: invalid escape sequence '\i'
#   help='Number of layers in neural network. $L\in\{3,5,7\}$.')
# /kaggle/working/sinn-reproduce/main_sinn.py:36: SyntaxWarning: invalid escape sequence '\i'
#   help='$\\alpha\in\{0.1,1.0,5.0\}$. ')
# /kaggle/working/sinn-reproduce/main_sinn.py:38: SyntaxWarning: invalid escape sequence '\i'
#   help='$\\beta\in\{0.1,1.0,5.0\}$. ')
# /kaggle/working/sinn-reproduce/main_sinn.py:43: SyntaxWarning: invalid escape sequence '\i'
#   help='dimension of latent space $K\in\{1,2,3\}$. ')
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1773650894.450932     150 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1773650894.457622     150 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1773650894.474687     150 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1773650894.474715     150 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1773650894.474720     150 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1773650894.474726     150 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# Loading dataset
# Finished loading dataset
# model(
#   (A): Embedding(200, 5)
#   (lamda): Embedding(200, 5)
# )
# Epoch 0, Train loss 4.393046, Val loss 5.659122, time 1.8463s
# Epoch 50, Train loss 0.008585, Val loss 0.028043, time 1.4440s
# Epoch 100, Train loss 0.004976, Val loss 0.014677, time 1.4102s
# Epoch 150, Train loss 0.004728, Val loss 0.013779, time 1.3897s
# Epoch 200, Train loss 0.004468, Val loss 0.014165, time 1.1011s
# Epoch 250, Train loss 0.004265, Val loss 0.015157, time 1.3731s
# Epoch 300, Train loss 0.004112, Val loss 0.016451, time 1.0948s
# Epoch 350, Train loss 0.003990, Val loss 0.017861, time 1.1036s
# Epoch 400, Train loss 0.003894, Val loss 0.019298, time 1.1016s
# Epoch 450, Train loss 0.003823, Val loss 0.020581, time 1.0924s
# #######################################
# ## Performance for DeGroot on synthetic_consensus dataset
# ## MAE: 0.298162026586216
# #######################################
#
# /kaggle/working/sinn-reproduce/main_sinn.py:32: SyntaxWarning: invalid escape sequence '\i'
#   help='Number of units in neural network. $L\in\{8,12,16\}$.')
# /kaggle/working/sinn-reproduce/main_sinn.py:34: SyntaxWarning: invalid escape sequence '\i'
#   help='Number of layers in neural network. $L\in\{3,5,7\}$.')
# /kaggle/working/sinn-reproduce/main_sinn.py:36: SyntaxWarning: invalid escape sequence '\i'
#   help='$\\alpha\in\{0.1,1.0,5.0\}$. ')
# /kaggle/working/sinn-reproduce/main_sinn.py:38: SyntaxWarning: invalid escape sequence '\i'
#   help='$\\beta\in\{0.1,1.0,5.0\}$. ')
# /kaggle/working/sinn-reproduce/main_sinn.py:43: SyntaxWarning: invalid escape sequence '\i'
#   help='dimension of latent space $K\in\{1,2,3\}$. ')
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1773651493.406749     169 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1773651493.413272     169 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1773651493.430179     169 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1773651493.430209     169 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1773651493.430214     169 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1773651493.430220     169 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# Loading dataset
# Finished loading dataset
# Epoch 0, Train loss 4001.169919, Val loss 3567.554703, time 1.6767s
# Epoch 50, Train loss 0.730585, Val loss 0.700638, time 1.1812s
# Epoch 100, Train loss 0.752540, Val loss 0.726219, time 1.4742s
# Epoch 150, Train loss 0.752930, Val loss 0.722856, time 1.1754s
# Epoch 200, Train loss 0.752648, Val loss 0.719422, time 1.4340s
# Epoch 250, Train loss 0.752247, Val loss 0.721973, time 1.1608s
# Epoch 300, Train loss 0.751914, Val loss 0.723470, time 1.1622s
# Epoch 350, Train loss 0.751660, Val loss 0.720401, time 1.1583s
# Epoch 400, Train loss 0.752042, Val loss 0.721066, time 1.1512s
# Epoch 450, Train loss 0.752267, Val loss 0.720659, time 1.1336s
# #######################################
# ## Performance for AsLM on synthetic_consensus dataset
# ## MAE: 0.5167165184327057
# #######################################
#
# /kaggle/working/sinn-reproduce/main_sinn.py:32: SyntaxWarning: invalid escape sequence '\i'
#   help='Number of units in neural network. $L\in\{8,12,16\}$.')
# /kaggle/working/sinn-reproduce/main_sinn.py:34: SyntaxWarning: invalid escape sequence '\i'
#   help='Number of layers in neural network. $L\in\{3,5,7\}$.')
# /kaggle/working/sinn-reproduce/main_sinn.py:36: SyntaxWarning: invalid escape sequence '\i'
#   help='$\\alpha\in\{0.1,1.0,5.0\}$. ')
# /kaggle/working/sinn-reproduce/main_sinn.py:38: SyntaxWarning: invalid escape sequence '\i'
#   help='$\\beta\in\{0.1,1.0,5.0\}$. ')
# /kaggle/working/sinn-reproduce/main_sinn.py:43: SyntaxWarning: invalid escape sequence '\i'
#   help='dimension of latent space $K\in\{1,2,3\}$. ')
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1773652400.035162     188 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1773652400.041789     188 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1773652400.058470     188 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1773652400.058498     188 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1773652400.058503     188 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1773652400.058508     188 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# Loading dataset
# Finished loading dataset
# Traceback (most recent call last):
#   File "/kaggle/working/sinn-reproduce/main_sinn.py", line 362, in <module>
#     main_sinn(opt.dataset, opt.method, logging_root)
#   File "/kaggle/working/sinn-reproduce/main_sinn.py", line 314, in main_sinn
#     training.train(model=model, train_dataloader=train_dataloader, val_dataloader=val_dataloader, epochs=num_epochs, lr=opt.lr,
#   File "/kaggle/working/sinn-reproduce/training.py", line 25, in train
#     model_output = model(model_input)
#                    ^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1775, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1786, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/kaggle/working/sinn-reproduce/src/slant.py", line 68, in forward
#     lamdai = F.softplus(raw_lambda) + 1e-6
#                         ^^^^^^^^^^
# NameError: name 'raw_lambda' is not defined. Did you mean: 'raw_lamdai'?
# /kaggle/working/sinn-reproduce/main_sinn.py:32: SyntaxWarning: invalid escape sequence '\i'
#   help='Number of units in neural network. $L\in\{8,12,16\}$.')
# /kaggle/working/sinn-reproduce/main_sinn.py:34: SyntaxWarning: invalid escape sequence '\i'
#   help='Number of layers in neural network. $L\in\{3,5,7\}$.')
# /kaggle/working/sinn-reproduce/main_sinn.py:36: SyntaxWarning: invalid escape sequence '\i'
#   help='$\\alpha\in\{0.1,1.0,5.0\}$. ')
# /kaggle/working/sinn-reproduce/main_sinn.py:38: SyntaxWarning: invalid escape sequence '\i'
#   help='$\\beta\in\{0.1,1.0,5.0\}$. ')
# /kaggle/working/sinn-reproduce/main_sinn.py:43: SyntaxWarning: invalid escape sequence '\i'
#   help='dimension of latent space $K\in\{1,2,3\}$. ')
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1773652412.097831     206 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1773652412.104689     206 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1773652412.122639     206 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1773652412.122670     206 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1773652412.122674     206 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1773652412.122678     206 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# Loading dataset
# Finished loading dataset
# Epoch 0, Train loss 0.794498, Val loss 0.738798, time 2.2938s
# Epoch 50, Train loss -5.986533, Val loss -6.043256, time 1.5304s
# Epoch 100, Train loss -31.719720, Val loss -31.341859, time 1.4990s
# Epoch 150, Train loss -9513.886789, Val loss -9308.286908, time 1.5734s
# Epoch 200, Train loss -3248156.692803, Val loss -3182661.834886, time 1.5818s
# Epoch 250, Train loss -982406300.433847, Val loss -962772847.571896, time 1.5786s
# Epoch 300, Train loss -275671472367.090210, Val loss -270090846172.457916, time 1.8574s
# Epoch 350, Train loss -73505194717242.531250, Val loss -71995005933630.656250, time 1.8212s
# Epoch 400, Train loss -18894109629210300.000000, Val loss -18500453424705816.000000, time 1.5500s
# Epoch 450, Train loss -4727301388529276928.000000, Val loss -4627700229342852096.000000, time 1.6050s
# #######################################
# ## Performance for SLANT+ on synthetic_consensus dataset
# ## MAE: 0.5168909013354599
# #######################################
#
# /kaggle/working/sinn-reproduce/main_sinn.py:32: SyntaxWarning: invalid escape sequence '\i'
#   help='Number of units in neural network. $L\in\{8,12,16\}$.')
# /kaggle/working/sinn-reproduce/main_sinn.py:34: SyntaxWarning: invalid escape sequence '\i'
#   help='Number of layers in neural network. $L\in\{3,5,7\}$.')
# /kaggle/working/sinn-reproduce/main_sinn.py:36: SyntaxWarning: invalid escape sequence '\i'
#   help='$\\alpha\in\{0.1,1.0,5.0\}$. ')
# /kaggle/working/sinn-reproduce/main_sinn.py:38: SyntaxWarning: invalid escape sequence '\i'
#   help='$\\beta\in\{0.1,1.0,5.0\}$. ')
# /kaggle/working/sinn-reproduce/main_sinn.py:43: SyntaxWarning: invalid escape sequence '\i'
#   help='dimension of latent space $K\in\{1,2,3\}$. ')
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1773653549.272359     225 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1773653549.279048     225 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1773653549.295849     225 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1773653549.295881     225 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1773653549.295886     225 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1773653549.295892     225 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# Loading dataset
# Finished loading dataset
# Traceback (most recent call last):
#   File "/kaggle/working/sinn-reproduce/main_sinn.py", line 362, in <module>
#     main_sinn(opt.dataset, opt.method, logging_root)
#   File "/kaggle/working/sinn-reproduce/main_sinn.py", line 303, in main_sinn
#     model = _method.model(type=opt.activation_func, num_users=num_users, hidden_features=opt.hidden_features,
#             ^^^^^^^^^^^^^
# AttributeError: module 'torch.nn' has no attribute 'model'
# /kaggle/working/sinn-reproduce/main_sinn.py:32: SyntaxWarning: invalid escape sequence '\i'
#   help='Number of units in neural network. $L\in\{8,12,16\}$.')
# /kaggle/working/sinn-reproduce/main_sinn.py:34: SyntaxWarning: invalid escape sequence '\i'
#   help='Number of layers in neural network. $L\in\{3,5,7\}$.')
# /kaggle/working/sinn-reproduce/main_sinn.py:36: SyntaxWarning: invalid escape sequence '\i'
#   help='$\\alpha\in\{0.1,1.0,5.0\}$. ')
# /kaggle/working/sinn-reproduce/main_sinn.py:38: SyntaxWarning: invalid escape sequence '\i'
#   help='$\\beta\in\{0.1,1.0,5.0\}$. ')
# /kaggle/working/sinn-reproduce/main_sinn.py:43: SyntaxWarning: invalid escape sequence '\i'
#   help='dimension of latent space $K\in\{1,2,3\}$. ')
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1773653559.700294     241 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1773653559.707033     241 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1773653559.723672     241 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1773653559.723701     241 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1773653559.723705     241 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1773653559.723708     241 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# Loading dataset
# Finished loading dataset
# Epoch 0, Train loss 1.599150, Val loss 1.455138, time 2.6718s
# Epoch 50, Train loss 1.046589, Val loss 0.859992, time 2.5105s
# Epoch 100, Train loss 0.934530, Val loss 0.812753, time 2.1396s
# Epoch 150, Train loss 0.845978, Val loss 0.751068, time 2.1493s
# Epoch 200, Train loss 0.833087, Val loss 0.817703, time 2.1628s
# Epoch 250, Train loss 0.734857, Val loss 0.703498, time 2.1654s
# Epoch 300, Train loss 0.699562, Val loss 0.690296, time 2.1125s
# Epoch 350, Train loss 0.693337, Val loss 0.650041, time 2.0925s
# Epoch 400, Train loss 0.646229, Val loss 0.640390, time 2.3805s
# Epoch 450, Train loss 0.652898, Val loss 0.636776, time 2.2602s
# #######################################
# ## Performance for SINN on synthetic_consensus dataset
# ## MAE: 0.8313773808186778
# ## ACC: 0.6552545155993432   F1: 0.49668554088841327
# #######################################
#
# /kaggle/working/sinn-reproduce/main_sinn.py:32: SyntaxWarning: invalid escape sequence '\i'
#   help='Number of units in neural network. $L\in\{8,12,16\}$.')
# /kaggle/working/sinn-reproduce/main_sinn.py:34: SyntaxWarning: invalid escape sequence '\i'
#   help='Number of layers in neural network. $L\in\{3,5,7\}$.')
# /kaggle/working/sinn-reproduce/main_sinn.py:36: SyntaxWarning: invalid escape sequence '\i'
#   help='$\\alpha\in\{0.1,1.0,5.0\}$. ')
# /kaggle/working/sinn-reproduce/main_sinn.py:38: SyntaxWarning: invalid escape sequence '\i'
#   help='$\\beta\in\{0.1,1.0,5.0\}$. ')
# /kaggle/working/sinn-reproduce/main_sinn.py:43: SyntaxWarning: invalid escape sequence '\i'
#   help='dimension of latent space $K\in\{1,2,3\}$. ')
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1773654687.389959     260 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1773654687.397200     260 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1773654687.414951     260 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1773654687.414986     260 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1773654687.414990     260 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1773654687.414993     260 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# Loading dataset
# Finished loading dataset
# Traceback (most recent call last):
#   File "/kaggle/working/sinn-reproduce/main_sinn.py", line 362, in <module>
#     main_sinn(opt.dataset, opt.method, logging_root)
#   File "/kaggle/working/sinn-reproduce/main_sinn.py", line 329, in main_sinn
#     test_res, att_res, zu_res = prediction(use_profile, test_dataloader, model, batch_size, nclasses)
#                                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/kaggle/working/sinn-reproduce/main_sinn.py", line 183, in prediction
#     device = next(model.parameters()).device
#              ^^^^^^^^^^^^^^^^^^^^^^^^
# StopIteration
# /kaggle/working/sinn-reproduce/main_sinn.py:32: SyntaxWarning: invalid escape sequence '\i'
#   help='Number of units in neural network. $L\in\{8,12,16\}$.')
# /kaggle/working/sinn-reproduce/main_sinn.py:34: SyntaxWarning: invalid escape sequence '\i'
#   help='Number of layers in neural network. $L\in\{3,5,7\}$.')
# /kaggle/working/sinn-reproduce/main_sinn.py:36: SyntaxWarning: invalid escape sequence '\i'
#   help='$\\alpha\in\{0.1,1.0,5.0\}$. ')
# /kaggle/working/sinn-reproduce/main_sinn.py:38: SyntaxWarning: invalid escape sequence '\i'
#   help='$\\beta\in\{0.1,1.0,5.0\}$. ')
# /kaggle/working/sinn-reproduce/main_sinn.py:43: SyntaxWarning: invalid escape sequence '\i'
#   help='dimension of latent space $K\in\{1,2,3\}$. ')
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1773654698.438475     278 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1773654698.445036     278 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1773654698.461770     278 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1773654698.461798     278 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1773654698.461803     278 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1773654698.461809     278 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# Loading dataset
# Finished loading dataset
# model(
#   (A): Embedding(200, 5)
#   (lamda): Embedding(200, 5)
# )
# Epoch 0, Train loss 3.483322, Val loss 3.367595, time 2.8110s
# Epoch 50, Train loss 0.001505, Val loss 0.009008, time 2.2909s
# Epoch 100, Train loss 0.001385, Val loss 0.008388, time 2.3513s
# Epoch 150, Train loss 0.001343, Val loss 0.008709, time 2.3235s
# Epoch 200, Train loss 0.001318, Val loss 0.009228, time 2.5667s
# Epoch 250, Train loss 0.001302, Val loss 0.009757, time 2.3306s
# Epoch 300, Train loss 0.001293, Val loss 0.010158, time 2.3563s
# Epoch 350, Train loss 0.001288, Val loss 0.010402, time 2.3131s
# Epoch 400, Train loss 0.001279, Val loss 0.010618, time 2.5243s
# Epoch 450, Train loss 0.001273, Val loss 0.010759, time 2.3267s
# #######################################
# ## Performance for DeGroot on synthetic_clustering dataset
# ## MAE: 0.1560848375380261
# #######################################
#
# /kaggle/working/sinn-reproduce/main_sinn.py:32: SyntaxWarning: invalid escape sequence '\i'
#   help='Number of units in neural network. $L\in\{8,12,16\}$.')
# /kaggle/working/sinn-reproduce/main_sinn.py:34: SyntaxWarning: invalid escape sequence '\i'
#   help='Number of layers in neural network. $L\in\{3,5,7\}$.')
# /kaggle/working/sinn-reproduce/main_sinn.py:36: SyntaxWarning: invalid escape sequence '\i'
#   help='$\\alpha\in\{0.1,1.0,5.0\}$. ')
# /kaggle/working/sinn-reproduce/main_sinn.py:38: SyntaxWarning: invalid escape sequence '\i'
#   help='$\\beta\in\{0.1,1.0,5.0\}$. ')
# /kaggle/working/sinn-reproduce/main_sinn.py:43: SyntaxWarning: invalid escape sequence '\i'
#   help='dimension of latent space $K\in\{1,2,3\}$. ')
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1773655940.523877     297 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1773655940.530437     297 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1773655940.547594     297 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1773655940.547625     297 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1773655940.547638     297 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1773655940.547643     297 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# Loading dataset
# Finished loading dataset
# Epoch 0, Train loss 3914.910421, Val loss 3221.981267, time 2.8478s
# Epoch 50, Train loss 0.865500, Val loss 0.910117, time 2.3417s
# Epoch 100, Train loss 0.867660, Val loss 0.911681, time 2.3438s
# Epoch 150, Train loss 0.867508, Val loss 0.909856, time 2.2308s
# Epoch 200, Train loss 0.868056, Val loss 0.911404, time 2.5371s
# Epoch 250, Train loss 0.868572, Val loss 0.912145, time 2.5700s
# Epoch 300, Train loss 0.867665, Val loss 0.914604, time 2.2655s
# Epoch 350, Train loss 0.868184, Val loss 0.910298, time 2.5294s
# Epoch 400, Train loss 0.869456, Val loss 0.916052, time 2.2476s
# Epoch 450, Train loss 0.869349, Val loss 0.911532, time 2.3292s
# #######################################
# ## Performance for AsLM on synthetic_clustering dataset
# ## MAE: 0.6254393323920773
# #######################################
#
# /kaggle/working/sinn-reproduce/main_sinn.py:32: SyntaxWarning: invalid escape sequence '\i'
#   help='Number of units in neural network. $L\in\{8,12,16\}$.')
# /kaggle/working/sinn-reproduce/main_sinn.py:34: SyntaxWarning: invalid escape sequence '\i'
#   help='Number of layers in neural network. $L\in\{3,5,7\}$.')
# /kaggle/working/sinn-reproduce/main_sinn.py:36: SyntaxWarning: invalid escape sequence '\i'
#   help='$\\alpha\in\{0.1,1.0,5.0\}$. ')
# /kaggle/working/sinn-reproduce/main_sinn.py:38: SyntaxWarning: invalid escape sequence '\i'
#   help='$\\beta\in\{0.1,1.0,5.0\}$. ')
# /kaggle/working/sinn-reproduce/main_sinn.py:43: SyntaxWarning: invalid escape sequence '\i'
#   help='dimension of latent space $K\in\{1,2,3\}$. ')
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1773658351.584979     316 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1773658351.591721     316 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1773658351.608510     316 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1773658351.608540     316 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1773658351.608543     316 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1773658351.608547     316 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# Loading dataset
# Finished loading dataset
# Traceback (most recent call last):
#   File "/kaggle/working/sinn-reproduce/main_sinn.py", line 362, in <module>
#     main_sinn(opt.dataset, opt.method, logging_root)
#   File "/kaggle/working/sinn-reproduce/main_sinn.py", line 314, in main_sinn
#     training.train(model=model, train_dataloader=train_dataloader, val_dataloader=val_dataloader, epochs=num_epochs, lr=opt.lr,
#   File "/kaggle/working/sinn-reproduce/training.py", line 25, in train
#     model_output = model(model_input)
#                    ^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1775, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1786, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/kaggle/working/sinn-reproduce/src/slant.py", line 68, in forward
#     lamdai = F.softplus(raw_lambda) + 1e-6
#                         ^^^^^^^^^^
# NameError: name 'raw_lambda' is not defined. Did you mean: 'raw_lamdai'?
# /kaggle/working/sinn-reproduce/main_sinn.py:32: SyntaxWarning: invalid escape sequence '\i'
#   help='Number of units in neural network. $L\in\{8,12,16\}$.')
# /kaggle/working/sinn-reproduce/main_sinn.py:34: SyntaxWarning: invalid escape sequence '\i'
#   help='Number of layers in neural network. $L\in\{3,5,7\}$.')
# /kaggle/working/sinn-reproduce/main_sinn.py:36: SyntaxWarning: invalid escape sequence '\i'
#   help='$\\alpha\in\{0.1,1.0,5.0\}$. ')
# /kaggle/working/sinn-reproduce/main_sinn.py:38: SyntaxWarning: invalid escape sequence '\i'
#   help='$\\beta\in\{0.1,1.0,5.0\}$. ')
# /kaggle/working/sinn-reproduce/main_sinn.py:43: SyntaxWarning: invalid escape sequence '\i'
#   help='dimension of latent space $K\in\{1,2,3\}$. ')
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1773658363.843149     334 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1773658363.849925     334 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1773658363.867045     334 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1773658363.867073     334 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1773658363.867078     334 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1773658363.867084     334 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# Loading dataset
# Finished loading dataset
# Epoch 0, Train loss 0.734320, Val loss 0.598829, time 3.6086s
# Epoch 50, Train loss -16.059017, Val loss -16.381790, time 3.2551s
# Epoch 100, Train loss -401781.075695, Val loss -415389.916930, time 3.2188s
# Epoch 150, Train loss -17096592383.345724, Val loss -17647918739.390022, time 3.2498s
# Epoch 200, Train loss -591796159695179.250000, Val loss -610086380964524.625000, time 3.0416s
# Epoch 250, Train loss -5540106257726638080.000000, Val loss -5165583032114803712.000000, time 3.0915s
# Epoch 300, Train loss -6598726663313729536.000000, Val loss -6128148611861793792.000000, time 2.9553s
# Epoch 350, Train loss -11645984049342382080.000000, Val loss -23666359565329932288.000000, time 2.9057s
# Epoch 400, Train loss -15280058534881417216.000000, Val loss -24078221663408448602112.000000, time 2.8657s
# Epoch 450, Train loss -17089860781042948096.000000, Val loss -43355077990177372156985344.000000, time 2.8545s
# #######################################
# ## Performance for SLANT+ on synthetic_clustering dataset
# ## MAE: 0.6255176834749533
# #######################################
#
# /kaggle/working/sinn-reproduce/main_sinn.py:32: SyntaxWarning: invalid escape sequence '\i'
#   help='Number of units in neural network. $L\in\{8,12,16\}$.')
# /kaggle/working/sinn-reproduce/main_sinn.py:34: SyntaxWarning: invalid escape sequence '\i'
#   help='Number of layers in neural network. $L\in\{3,5,7\}$.')
# /kaggle/working/sinn-reproduce/main_sinn.py:36: SyntaxWarning: invalid escape sequence '\i'
#   help='$\\alpha\in\{0.1,1.0,5.0\}$. ')
# /kaggle/working/sinn-reproduce/main_sinn.py:38: SyntaxWarning: invalid escape sequence '\i'
#   help='$\\beta\in\{0.1,1.0,5.0\}$. ')
# /kaggle/working/sinn-reproduce/main_sinn.py:43: SyntaxWarning: invalid escape sequence '\i'
#   help='dimension of latent space $K\in\{1,2,3\}$. ')
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1773661174.734882     353 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1773661174.742016     353 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1773661174.759626     353 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1773661174.759664     353 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1773661174.759667     353 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1773661174.759671     353 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# Loading dataset
# Finished loading dataset
# Traceback (most recent call last):
#   File "/kaggle/working/sinn-reproduce/main_sinn.py", line 362, in <module>
#     main_sinn(opt.dataset, opt.method, logging_root)
#   File "/kaggle/working/sinn-reproduce/main_sinn.py", line 303, in main_sinn
#     model = _method.model(type=opt.activation_func, num_users=num_users, hidden_features=opt.hidden_features,
#             ^^^^^^^^^^^^^
# AttributeError: module 'torch.nn' has no attribute 'model'
# /kaggle/working/sinn-reproduce/main_sinn.py:32: SyntaxWarning: invalid escape sequence '\i'
#   help='Number of units in neural network. $L\in\{8,12,16\}$.')
# /kaggle/working/sinn-reproduce/main_sinn.py:34: SyntaxWarning: invalid escape sequence '\i'
#   help='Number of layers in neural network. $L\in\{3,5,7\}$.')
# /kaggle/working/sinn-reproduce/main_sinn.py:36: SyntaxWarning: invalid escape sequence '\i'
#   help='$\\alpha\in\{0.1,1.0,5.0\}$. ')
# /kaggle/working/sinn-reproduce/main_sinn.py:38: SyntaxWarning: invalid escape sequence '\i'
#   help='$\\beta\in\{0.1,1.0,5.0\}$. ')
# /kaggle/working/sinn-reproduce/main_sinn.py:43: SyntaxWarning: invalid escape sequence '\i'
#   help='dimension of latent space $K\in\{1,2,3\}$. ')
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1773661185.739995     369 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1773661185.746694     369 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1773661185.764638     369 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1773661185.764678     369 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1773661185.764684     369 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1773661185.764690     369 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# Loading dataset
# Finished loading dataset
# Epoch 0, Train loss 1.618759, Val loss 1.528698, time 5.0896s
# Epoch 50, Train loss 0.808217, Val loss 1.140014, time 4.7456s
# Epoch 100, Train loss 0.685081, Val loss 1.188241, time 4.4966s
# Epoch 150, Train loss 0.633599, Val loss 1.240417, time 4.4325s
# Epoch 200, Train loss 0.628285, Val loss 1.252215, time 4.6927s
# Epoch 250, Train loss 0.530942, Val loss 1.366212, time 4.3387s
# Epoch 300, Train loss 0.742189, Val loss 1.239504, time 4.3407s
# Epoch 350, Train loss 0.477432, Val loss 1.350182, time 4.5274s
# Epoch 400, Train loss 0.549214, Val loss 1.412802, time 4.4327s
# Epoch 450, Train loss 0.528388, Val loss 1.395478, time 4.6809s
# #######################################
# ## Performance for SINN on synthetic_clustering dataset
# ## MAE: 0.8468892976721769
# ## ACC: 0.7124069478908188   F1: 0.6955190014024815
# #######################################
#
# /kaggle/working/sinn-reproduce/main_sinn.py:32: SyntaxWarning: invalid escape sequence '\i'
#   help='Number of units in neural network. $L\in\{8,12,16\}$.')
# /kaggle/working/sinn-reproduce/main_sinn.py:34: SyntaxWarning: invalid escape sequence '\i'
#   help='Number of layers in neural network. $L\in\{3,5,7\}$.')
# /kaggle/working/sinn-reproduce/main_sinn.py:36: SyntaxWarning: invalid escape sequence '\i'
#   help='$\\alpha\in\{0.1,1.0,5.0\}$. ')
# /kaggle/working/sinn-reproduce/main_sinn.py:38: SyntaxWarning: invalid escape sequence '\i'
#   help='$\\beta\in\{0.1,1.0,5.0\}$. ')
# /kaggle/working/sinn-reproduce/main_sinn.py:43: SyntaxWarning: invalid escape sequence '\i'
#   help='dimension of latent space $K\in\{1,2,3\}$. ')
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1773663504.499402     388 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1773663504.506688     388 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1773663504.523471     388 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1773663504.523509     388 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1773663504.523512     388 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1773663504.523516     388 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# Loading dataset
# Finished loading dataset
# Traceback (most recent call last):
#   File "/kaggle/working/sinn-reproduce/main_sinn.py", line 362, in <module>
#     main_sinn(opt.dataset, opt.method, logging_root)
#   File "/kaggle/working/sinn-reproduce/main_sinn.py", line 329, in main_sinn
#     test_res, att_res, zu_res = prediction(use_profile, test_dataloader, model, batch_size, nclasses)
#                                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/kaggle/working/sinn-reproduce/main_sinn.py", line 183, in prediction
#     device = next(model.parameters()).device
#              ^^^^^^^^^^^^^^^^^^^^^^^^
# StopIteration
# /kaggle/working/sinn-reproduce/main_sinn.py:32: SyntaxWarning: invalid escape sequence '\i'
#   help='Number of units in neural network. $L\in\{8,12,16\}$.')
# /kaggle/working/sinn-reproduce/main_sinn.py:34: SyntaxWarning: invalid escape sequence '\i'
#   help='Number of layers in neural network. $L\in\{3,5,7\}$.')
# /kaggle/working/sinn-reproduce/main_sinn.py:36: SyntaxWarning: invalid escape sequence '\i'
#   help='$\\alpha\in\{0.1,1.0,5.0\}$. ')
# /kaggle/working/sinn-reproduce/main_sinn.py:38: SyntaxWarning: invalid escape sequence '\i'
#   help='$\\beta\in\{0.1,1.0,5.0\}$. ')
# /kaggle/working/sinn-reproduce/main_sinn.py:43: SyntaxWarning: invalid escape sequence '\i'
#   help='dimension of latent space $K\in\{1,2,3\}$. ')
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1773663515.298048     406 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1773663515.304833     406 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1773663515.322325     406 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1773663515.322356     406 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1773663515.322361     406 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1773663515.322366     406 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# Loading dataset
# Finished loading dataset
# model(
#   (A): Embedding(200, 5)
#   (lamda): Embedding(200, 5)
# )
# Epoch 0, Train loss 4.237014, Val loss 5.570289, time 1.7216s
# Epoch 50, Train loss 0.004748, Val loss 0.022653, time 1.2304s
# Epoch 100, Train loss 0.001703, Val loss 0.009943, time 1.5342s
# Epoch 150, Train loss 0.001525, Val loss 0.009703, time 1.2089s
# Epoch 200, Train loss 0.001397, Val loss 0.010188, time 1.4984s
# Epoch 250, Train loss 0.001318, Val loss 0.010754, time 1.1522s
# Epoch 300, Train loss 0.001267, Val loss 0.011248, time 1.1972s
# Epoch 350, Train loss 0.001233, Val loss 0.011587, time 1.1959s
# Epoch 400, Train loss 0.001210, Val loss 0.011822, time 1.2259s
# Epoch 450, Train loss 0.001194, Val loss 0.012001, time 1.1697s
# #######################################
# ## Performance for DeGroot on synthetic_polarization dataset
# ## MAE: 0.1615188967038943
# #######################################
#
# /kaggle/working/sinn-reproduce/main_sinn.py:32: SyntaxWarning: invalid escape sequence '\i'
#   help='Number of units in neural network. $L\in\{8,12,16\}$.')
# /kaggle/working/sinn-reproduce/main_sinn.py:34: SyntaxWarning: invalid escape sequence '\i'
#   help='Number of layers in neural network. $L\in\{3,5,7\}$.')
# /kaggle/working/sinn-reproduce/main_sinn.py:36: SyntaxWarning: invalid escape sequence '\i'
#   help='$\\alpha\in\{0.1,1.0,5.0\}$. ')
# /kaggle/working/sinn-reproduce/main_sinn.py:38: SyntaxWarning: invalid escape sequence '\i'
#   help='$\\beta\in\{0.1,1.0,5.0\}$. ')
# /kaggle/working/sinn-reproduce/main_sinn.py:43: SyntaxWarning: invalid escape sequence '\i'
#   help='dimension of latent space $K\in\{1,2,3\}$. ')
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1773664164.059768     425 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1773664164.066685     425 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1773664164.084329     425 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1773664164.084360     425 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1773664164.084363     425 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1773664164.084367     425 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# Loading dataset
# Finished loading dataset
# Epoch 0, Train loss 3706.571008, Val loss 3259.767231, time 1.7103s
# Epoch 50, Train loss 0.790876, Val loss 0.811666, time 1.1821s
# Epoch 100, Train loss 0.812525, Val loss 0.834535, time 1.4128s
# Epoch 150, Train loss 0.812599, Val loss 0.834293, time 1.2001s
# Epoch 200, Train loss 0.812461, Val loss 0.834816, time 1.4430s
# Epoch 250, Train loss 0.812933, Val loss 0.833656, time 1.1802s
# Epoch 300, Train loss 0.813188, Val loss 0.836097, time 1.1910s
# Epoch 350, Train loss 0.813010, Val loss 0.833432, time 1.2115s
# Epoch 400, Train loss 0.812886, Val loss 0.835415, time 1.1767s
# Epoch 450, Train loss 0.813044, Val loss 0.832463, time 1.1902s
# #######################################
# ## Performance for AsLM on synthetic_polarization dataset
# ## MAE: 0.46614642558068564
# #######################################
#
# /kaggle/working/sinn-reproduce/main_sinn.py:32: SyntaxWarning: invalid escape sequence '\i'
#   help='Number of units in neural network. $L\in\{8,12,16\}$.')
# /kaggle/working/sinn-reproduce/main_sinn.py:34: SyntaxWarning: invalid escape sequence '\i'
#   help='Number of layers in neural network. $L\in\{3,5,7\}$.')
# /kaggle/working/sinn-reproduce/main_sinn.py:36: SyntaxWarning: invalid escape sequence '\i'
#   help='$\\alpha\in\{0.1,1.0,5.0\}$. ')
# /kaggle/working/sinn-reproduce/main_sinn.py:38: SyntaxWarning: invalid escape sequence '\i'
#   help='$\\beta\in\{0.1,1.0,5.0\}$. ')
# /kaggle/working/sinn-reproduce/main_sinn.py:43: SyntaxWarning: invalid escape sequence '\i'
#   help='dimension of latent space $K\in\{1,2,3\}$. ')
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1773665072.311249     444 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1773665072.318623     444 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1773665072.339185     444 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1773665072.339218     444 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1773665072.339226     444 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1773665072.339231     444 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# Loading dataset
# Finished loading dataset
# Traceback (most recent call last):
#   File "/kaggle/working/sinn-reproduce/main_sinn.py", line 362, in <module>
#     main_sinn(opt.dataset, opt.method, logging_root)
#   File "/kaggle/working/sinn-reproduce/main_sinn.py", line 314, in main_sinn
#     training.train(model=model, train_dataloader=train_dataloader, val_dataloader=val_dataloader, epochs=num_epochs, lr=opt.lr,
#   File "/kaggle/working/sinn-reproduce/training.py", line 25, in train
#     model_output = model(model_input)
#                    ^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1775, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1786, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/kaggle/working/sinn-reproduce/src/slant.py", line 68, in forward
#     lamdai = F.softplus(raw_lambda) + 1e-6
#                         ^^^^^^^^^^
# NameError: name 'raw_lambda' is not defined. Did you mean: 'raw_lamdai'?
# /kaggle/working/sinn-reproduce/main_sinn.py:32: SyntaxWarning: invalid escape sequence '\i'
#   help='Number of units in neural network. $L\in\{8,12,16\}$.')
# /kaggle/working/sinn-reproduce/main_sinn.py:34: SyntaxWarning: invalid escape sequence '\i'
#   help='Number of layers in neural network. $L\in\{3,5,7\}$.')
# /kaggle/working/sinn-reproduce/main_sinn.py:36: SyntaxWarning: invalid escape sequence '\i'
#   help='$\\alpha\in\{0.1,1.0,5.0\}$. ')
# /kaggle/working/sinn-reproduce/main_sinn.py:38: SyntaxWarning: invalid escape sequence '\i'
#   help='$\\beta\in\{0.1,1.0,5.0\}$. ')
# /kaggle/working/sinn-reproduce/main_sinn.py:43: SyntaxWarning: invalid escape sequence '\i'
#   help='dimension of latent space $K\in\{1,2,3\}$. ')
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1773665084.398946     462 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1773665084.405746     462 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1773665084.422900     462 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1773665084.422927     462 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1773665084.422930     462 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1773665084.422933     462 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# Loading dataset
# Finished loading dataset
# Epoch 0, Train loss 0.794487, Val loss 0.738783, time 2.2105s
# Epoch 50, Train loss -5.987328, Val loss -6.044198, time 1.5296s
# Epoch 100, Train loss -31.712747, Val loss -31.333215, time 1.5292s
# Epoch 150, Train loss -9509.414919, Val loss -9303.865948, time 1.4741s
# Epoch 200, Train loss -3246635.315800, Val loss -3181180.882217, time 1.5426s
# Epoch 250, Train loss -981937781.039198, Val loss -962315949.923293, time 1.5726s
# Epoch 300, Train loss -275539500786.607422, Val loss -269965920472.767151, time 1.7523s
# Epoch 350, Train loss -73469328798509.562500, Val loss -71959450480392.656250, time 2.0077s
# Epoch 400, Train loss -18884666232422000.000000, Val loss -18491090356122616.000000, time 1.5549s
# Epoch 450, Train loss -4725000333594637312.000000, Val loss -4625405604774130688.000000, time 1.5843s
# #######################################
# ## Performance for SLANT+ on synthetic_polarization dataset
# ## MAE: 0.46620902419299187
# #######################################
#
# /kaggle/working/sinn-reproduce/main_sinn.py:32: SyntaxWarning: invalid escape sequence '\i'
#   help='Number of units in neural network. $L\in\{8,12,16\}$.')
# /kaggle/working/sinn-reproduce/main_sinn.py:34: SyntaxWarning: invalid escape sequence '\i'
#   help='Number of layers in neural network. $L\in\{3,5,7\}$.')
# /kaggle/working/sinn-reproduce/main_sinn.py:36: SyntaxWarning: invalid escape sequence '\i'
#   help='$\\alpha\in\{0.1,1.0,5.0\}$. ')
# /kaggle/working/sinn-reproduce/main_sinn.py:38: SyntaxWarning: invalid escape sequence '\i'
#   help='$\\beta\in\{0.1,1.0,5.0\}$. ')
# /kaggle/working/sinn-reproduce/main_sinn.py:43: SyntaxWarning: invalid escape sequence '\i'
#   help='dimension of latent space $K\in\{1,2,3\}$. ')
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1773666216.479692     481 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1773666216.486461     481 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1773666216.503513     481 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1773666216.503548     481 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1773666216.503552     481 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1773666216.503555     481 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# Loading dataset
# Finished loading dataset
# Traceback (most recent call last):
#   File "/kaggle/working/sinn-reproduce/main_sinn.py", line 362, in <module>
#     main_sinn(opt.dataset, opt.method, logging_root)
#   File "/kaggle/working/sinn-reproduce/main_sinn.py", line 303, in main_sinn
#     model = _method.model(type=opt.activation_func, num_users=num_users, hidden_features=opt.hidden_features,
#             ^^^^^^^^^^^^^
# AttributeError: module 'torch.nn' has no attribute 'model'
# /kaggle/working/sinn-reproduce/main_sinn.py:32: SyntaxWarning: invalid escape sequence '\i'
#   help='Number of units in neural network. $L\in\{8,12,16\}$.')
# /kaggle/working/sinn-reproduce/main_sinn.py:34: SyntaxWarning: invalid escape sequence '\i'
#   help='Number of layers in neural network. $L\in\{3,5,7\}$.')
# /kaggle/working/sinn-reproduce/main_sinn.py:36: SyntaxWarning: invalid escape sequence '\i'
#   help='$\\alpha\in\{0.1,1.0,5.0\}$. ')
# /kaggle/working/sinn-reproduce/main_sinn.py:38: SyntaxWarning: invalid escape sequence '\i'
#   help='$\\beta\in\{0.1,1.0,5.0\}$. ')
# /kaggle/working/sinn-reproduce/main_sinn.py:43: SyntaxWarning: invalid escape sequence '\i'
#   help='dimension of latent space $K\in\{1,2,3\}$. ')
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1773666227.249285     497 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1773666227.255974     497 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1773666227.272470     497 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1773666227.272503     497 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1773666227.272507     497 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1773666227.272510     497 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# Loading dataset
# Finished loading dataset
# Epoch 0, Train loss 1.725718, Val loss 1.667746, time 2.6741s
# Epoch 50, Train loss 0.926482, Val loss 0.774387, time 2.5298s
# Epoch 100, Train loss 0.780056, Val loss 0.710154, time 2.2022s
# Epoch 150, Train loss 0.678731, Val loss 0.665555, time 2.1637s
# Epoch 200, Train loss 0.649505, Val loss 0.656512, time 2.2484s
# Epoch 250, Train loss 0.608842, Val loss 0.651651, time 2.1333s
# Epoch 300, Train loss 0.600727, Val loss 0.663891, time 2.2855s
# Epoch 350, Train loss 0.578315, Val loss 0.664357, time 2.2714s
# Epoch 400, Train loss 0.554088, Val loss 0.657790, time 2.5182s
# Epoch 450, Train loss 0.588949, Val loss 0.758821, time 2.2481s
# #######################################
# ## Performance for SINN on synthetic_polarization dataset
# ## MAE: 1.0448293179854726
# ## ACC: 0.7553366174055829   F1: 0.5923931549308941
# #######################################
