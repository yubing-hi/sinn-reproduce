# %%
import torch
print(torch.cuda.is_available())
# Out:
# True

# %%
# !git clone https://github.com/yubing-hi/sinn-reproduce.git
# %cd sinn-reproduce
# Out:
# Cloning into 'sinn-reproduce'...
# remote: Enumerating objects: 107, done.
# remote: Counting objects: 100% (107/107), done.
# remote: Compressing objects: 100% (72/72), done.
# remote: Total 107 (delta 49), reused 88 (delta 32), pack-reused 0 (from 0)
# Receiving objects: 100% (107/107), 1.29 MiB | 2.77 MiB/s, done.
# Resolving deltas: 100% (49/49), done.
# /kaggle/working/sinn-reproduce/sinn-reproduce

# %%
# !pwd
# !ls
# Out:
# /kaggle/working/sinn-reproduce
# collect_reddit.py		 input		     run_grid_search.sh
# collect_twitter.py		 main_sinn.py	     simulate.py
# collect_twitter_user.py		 modules.py	     src
# convert_data.py			 plotting.py	     test.sh
# CONVERT_DATA_README.md		 preprocess.py	     training.py
# experiment_synthetic_test.ipynb  README.md	     working
# image				 run_all_methods.sh

# %%
# !git pull

# %%
# !pip install configargparse
# Out:
# Collecting configargparse
#   Downloading configargparse-1.7.5-py3-none-any.whl.metadata (23 kB)
# Downloading configargparse-1.7.5-py3-none-any.whl (27 kB)
# Installing collected packages: configargparse
# Successfully installed configargparse-1.7.5

# %%
import os
import sys
import torch

# !bash run_all_methods.sh
# Out:
# /kaggle/working/sinn-reproduce/sinn-reproduce/main_sinn.py:32: SyntaxWarning: invalid escape sequence '\i'
#   help='Number of units in neural network. $L\in\{8,12,16\}$.')
# /kaggle/working/sinn-reproduce/sinn-reproduce/main_sinn.py:34: SyntaxWarning: invalid escape sequence '\i'
#   help='Number of layers in neural network. $L\in\{3,5,7\}$.')
# /kaggle/working/sinn-reproduce/sinn-reproduce/main_sinn.py:36: SyntaxWarning: invalid escape sequence '\i'
#   help='$\\alpha\in\{0.1,1.0,5.0\}$. ')
# /kaggle/working/sinn-reproduce/sinn-reproduce/main_sinn.py:38: SyntaxWarning: invalid escape sequence '\i'
#   help='$\\beta\in\{0.1,1.0,5.0\}$. ')
# /kaggle/working/sinn-reproduce/sinn-reproduce/main_sinn.py:43: SyntaxWarning: invalid escape sequence '\i'
#   help='dimension of latent space $K\in\{1,2,3\}$. ')
# 2026-03-17 08:03:44.306269: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1773734624.330240     193 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1773734624.337166     193 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1773734624.355193     193 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1773734624.355238     193 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1773734624.355242     193 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1773734624.355246     193 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# Loading dataset
# Finished loading dataset
# Epoch 0, Train loss 1.599150, Val loss 1.455138, time 2.7644s
# Epoch 50, Train loss 1.261756, Val loss 1.161112, time 2.7881s
# Epoch 100, Train loss 1.218520, Val loss 1.131326, time 2.4552s
# Epoch 150, Train loss 1.220410, Val loss 1.139133, time 2.4174s
# Epoch 200, Train loss 1.219600, Val loss 1.136753, time 2.5161s
# Epoch 250, Train loss 1.219599, Val loss 1.136881, time 2.4328s
# Epoch 300, Train loss 1.212502, Val loss 1.116980, time 2.4809s
# Epoch 350, Train loss 1.225121, Val loss 1.109407, time 2.4742s
# Epoch 400, Train loss 1.225108, Val loss 1.110319, time 2.8407s
# Epoch 450, Train loss 1.225107, Val loss 1.110467, time 2.4281s
# #######################################
# ## Performance for SINN on synthetic_consensus dataset
# ## MAE: 1.1240761991204886
# ## ACC: 0.711247947454844   F1: 0.2936880437979932
# #######################################
#
# /kaggle/working/sinn-reproduce/sinn-reproduce/main_sinn.py:32: SyntaxWarning: invalid escape sequence '\i'
#   help='Number of units in neural network. $L\in\{8,12,16\}$.')
# /kaggle/working/sinn-reproduce/sinn-reproduce/main_sinn.py:34: SyntaxWarning: invalid escape sequence '\i'
#   help='Number of layers in neural network. $L\in\{3,5,7\}$.')
# /kaggle/working/sinn-reproduce/sinn-reproduce/main_sinn.py:36: SyntaxWarning: invalid escape sequence '\i'
#   help='$\\alpha\in\{0.1,1.0,5.0\}$. ')
# /kaggle/working/sinn-reproduce/sinn-reproduce/main_sinn.py:38: SyntaxWarning: invalid escape sequence '\i'
#   help='$\\beta\in\{0.1,1.0,5.0\}$. ')
# /kaggle/working/sinn-reproduce/sinn-reproduce/main_sinn.py:43: SyntaxWarning: invalid escape sequence '\i'
#   help='dimension of latent space $K\in\{1,2,3\}$. ')
# 2026-03-17 08:25:13.701786: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1773735913.724993     212 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1773735913.731792     212 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1773735913.749176     212 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1773735913.749215     212 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1773735913.749219     212 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1773735913.749222     212 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# Loading dataset
# Finished loading dataset
# Epoch 0, Train loss 1.590904, Val loss 1.520396, time 5.4260s
# Epoch 50, Train loss 1.247254, Val loss 1.382688, time 4.9959s
# Epoch 100, Train loss 1.253758, Val loss 1.397352, time 5.0528s
# Epoch 150, Train loss 1.244066, Val loss 1.395237, time 4.8764s
# Epoch 200, Train loss 1.244066, Val loss 1.395237, time 5.1455s
# Epoch 250, Train loss 1.248022, Val loss 1.390472, time 4.7366s
# Epoch 300, Train loss 1.276249, Val loss 1.398560, time 4.7255s
# Epoch 350, Train loss 1.276249, Val loss 1.398560, time 4.8470s
# Epoch 400, Train loss 1.276249, Val loss 1.398560, time 4.5492s
# Epoch 450, Train loss 1.276249, Val loss 1.398560, time 5.0804s
# #######################################
# ## Performance for SINN on synthetic_clustering dataset
# ## MAE: 0.9870346696713032
# ## ACC: 0.38713813068651776   F1: 0.19886039078606682
# #######################################
#
# /kaggle/working/sinn-reproduce/sinn-reproduce/main_sinn.py:32: SyntaxWarning: invalid escape sequence '\i'
#   help='Number of units in neural network. $L\in\{8,12,16\}$.')
# /kaggle/working/sinn-reproduce/sinn-reproduce/main_sinn.py:34: SyntaxWarning: invalid escape sequence '\i'
#   help='Number of layers in neural network. $L\in\{3,5,7\}$.')
# /kaggle/working/sinn-reproduce/sinn-reproduce/main_sinn.py:36: SyntaxWarning: invalid escape sequence '\i'
#   help='$\\alpha\in\{0.1,1.0,5.0\}$. ')
# /kaggle/working/sinn-reproduce/sinn-reproduce/main_sinn.py:38: SyntaxWarning: invalid escape sequence '\i'
#   help='$\\beta\in\{0.1,1.0,5.0\}$. ')
# /kaggle/working/sinn-reproduce/sinn-reproduce/main_sinn.py:43: SyntaxWarning: invalid escape sequence '\i'
#   help='dimension of latent space $K\in\{1,2,3\}$. ')
# 2026-03-17 09:06:40.046124: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1773738400.068892     231 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1773738400.075658     231 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1773738400.093464     231 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1773738400.093504     231 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1773738400.093511     231 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1773738400.093515     231 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# Loading dataset
# Finished loading dataset
# Epoch 0, Train loss 1.725609, Val loss 1.667104, time 2.6912s
# Epoch 50, Train loss 1.267937, Val loss 1.270772, time 2.6823s
# Epoch 100, Train loss 1.243677, Val loss 1.252823, time 2.2847s
# Epoch 150, Train loss 0.832441, Val loss 0.798588, time 2.4282s
# Epoch 200, Train loss 0.722773, Val loss 0.739995, time 2.2075s
# Epoch 250, Train loss 0.647116, Val loss 0.702390, time 2.1915s
# Epoch 300, Train loss 0.605145, Val loss 0.671683, time 2.2315s
# Epoch 350, Train loss 0.580653, Val loss 0.658725, time 2.2790s
# Epoch 400, Train loss 0.565343, Val loss 0.664693, time 2.5651s
# Epoch 450, Train loss 0.531231, Val loss 0.613963, time 2.3371s
# #######################################
# ## Performance for SINN on synthetic_polarization dataset
# ## MAE: 1.1510683009416256
# ## ACC: 0.8049261083743843   F1: 0.7456672419751551
# #######################################
