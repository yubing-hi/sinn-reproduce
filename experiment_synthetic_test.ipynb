# %%
import torch
print(torch.cuda.is_available())
# Out:
# True

# %%
# !git clone https://github.com/yubing-hi/sinn-reproduce.git
# %cd sinn-reproduce
# Out:
# Cloning into 'sinn-reproduce'...
# remote: Enumerating objects: 131, done.
# remote: Counting objects: 100% (131/131), done.
# remote: Compressing objects: 100% (86/86), done.
# remote: Total 131 (delta 67), reused 103 (delta 42), pack-reused 0 (from 0)
# Receiving objects: 100% (131/131), 1.30 MiB | 8.91 MiB/s, done.
# Resolving deltas: 100% (67/67), done.
# /kaggle/working/sinn-reproduce/sinn-reproduce

# %%
# !pwd
# !ls
# Out:
# /kaggle/working/sinn-reproduce
# collect_reddit.py		 input		     run_grid_search.sh
# collect_twitter.py		 main_sinn.py	     simulate.py
# collect_twitter_user.py		 modules.py	     src
# convert_data.py			 plotting.py	     test.sh
# CONVERT_DATA_README.md		 preprocess.py	     training.py
# experiment_synthetic_test.ipynb  README.md	     working
# image				 run_all_methods.sh

# %%
# !git pull

# %%
# !pip install configargparse
# Out:
# Collecting configargparse
#   Downloading configargparse-1.7.5-py3-none-any.whl.metadata (23 kB)
# Downloading configargparse-1.7.5-py3-none-any.whl (27 kB)
# Installing collected packages: configargparse
# Successfully installed configargparse-1.7.5

# %%
import os
import sys
import torch

# !bash run_all_methods.sh
# Out:
# /kaggle/working/sinn-reproduce/sinn-reproduce/main_sinn.py:32: SyntaxWarning: invalid escape sequence '\i'
#   help='Number of units in neural network. $L\in\{8,12,16\}$.')
# /kaggle/working/sinn-reproduce/sinn-reproduce/main_sinn.py:34: SyntaxWarning: invalid escape sequence '\i'
#   help='Number of layers in neural network. $L\in\{3,5,7\}$.')
# /kaggle/working/sinn-reproduce/sinn-reproduce/main_sinn.py:36: SyntaxWarning: invalid escape sequence '\i'
#   help='$\\alpha\in\{0.1,1.0,5.0\}$. ')
# /kaggle/working/sinn-reproduce/sinn-reproduce/main_sinn.py:38: SyntaxWarning: invalid escape sequence '\i'
#   help='$\\beta\in\{0.1,1.0,5.0\}$. ')
# /kaggle/working/sinn-reproduce/sinn-reproduce/main_sinn.py:43: SyntaxWarning: invalid escape sequence '\i'
#   help='dimension of latent space $K\in\{1,2,3\}$. ')
# 2026-03-19 05:28:11.013945: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1773898091.206655     130 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1773898091.272066     130 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1773898091.767138     130 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1773898091.767210     130 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1773898091.767232     130 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1773898091.767244     130 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# Loading dataset
# Finished loading dataset
# Epoch 0, Train loss 1.726381, Val loss 1.674730, time 3.1103s
# Epoch 50, Train loss 1.137013, Val loss 1.000948, time 2.0567s
# Epoch 100, Train loss 0.962800, Val loss 0.866917, time 2.1076s
# Epoch 150, Train loss 0.854830, Val loss 0.808512, time 2.4027s
# Epoch 200, Train loss 0.820713, Val loss 0.844381, time 2.2219s
# Epoch 250, Train loss 0.780017, Val loss 0.734985, time 2.1003s
# Epoch 300, Train loss 0.732461, Val loss 0.712638, time 2.1019s
# Epoch 350, Train loss 0.706908, Val loss 0.727590, time 2.0607s
# Epoch 400, Train loss 0.586159, Val loss 0.651243, time 2.1366s
# Epoch 450, Train loss 0.626266, Val loss 0.666751, time 2.1179s
# #######################################
# ## Performance for SINN on synthetic_polarization dataset
# ## MAE: 0.649757764248536
# ## ACC: 0.7277504105090312   F1: 0.6561892292757948
# #######################################
